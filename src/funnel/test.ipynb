# %%
from utils_funnel import main_funnel_daily

if __name__ == "__main__":
    # Выбираем нужное количество дней
    days_count = 1
    # Получаем данные
    await main_funnel_daily(days_count)
