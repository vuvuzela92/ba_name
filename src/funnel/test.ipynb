# %%
from utils_funnel import main_funnel_daily

if __name__ == "__main__":
    # Выбираем нужное количество дней
    days_count = 1
    # Получаем данные
    await main_funnel_daily(days_count)
# Out:
# 📅 Запрашиваем данные за 2 дней...
# ✅ Получено 2 записей
# 📦 Обработано 0 товаров
# ⚡ DataFrame создан: 0 строк за 2 дней
# Добавляем заголовки и данные
# Дата и время последнего обновления: 2025-11-26 22:06:10
