# %%
import pandas as pd
from utils_advert import get_all_adv_data, processed_adv_data, safe_open_spreadsheet, send_df_to_google
import asyncio


if __name__ == "__main__":
    adv_data = await get_all_adv_data()
    adv_processed_data = processed_adv_data(adv_data)
    df = pd.DataFrame(adv_processed_data)
    # Добавляем данные о cpm рекламной кампании
    df['cpm'] = (df['sum']/df['views'] * 1000).round(2)
    # Выбираем нужные для отображения в гугл-таблице колонки
    using_cols = ['date', 'avg_position', 'cr', 'atbs', 'article_id', 'advertId', 'views', 'clicks', 'sum', 'orders', 'sum_price', 'canceled', 'ctr', 'cpc', 'cpm', 'account']
    # Создаем из них датафрейм
    df_short = df[using_cols]

    df_short.drop_duplicates
    table = safe_open_spreadsheet("victoria_project")
    sheet = table.worksheet("БД_Рекламная_статистика")
    send_df_to_google(df_short, sheet)
# Out:
# Получаем данные за 2025-11-25 по ЛК Папшева
# Запрос для Папшева: {'ids': '24822792,30073866,22204941,21554193,22867992,29370398,30223392,28191265,19577376,29985835,23712813,29370414,25659439,24824369,19735608,21481529,22517825,24997965,29514324,30566999,26307674,30425691,22692442,23716447,21299300,21192805,19576953,30296205,20186773,21192857,29268634,19577503,19702440,29268661,25686209,28699850,26842834,26081493,23679705,29901029,19577581,29397230,19577591,20856056,29931260,20514569,22868235,20497176,28467497,27193658,27918657,28955970,20838210,27054408,29419340,18992973,28344148,28467546,29682013,19808101,21133160,29683571,19823992,21193606,20008842,26643342,19691925,19600293,23285161,19577261,23931314,20780981,29472695,27056058,27132353,20828617,26966476,29619153,27023854,28354556', 'beginDate': '2025-11-25', 'endDate': '2025-11-25'}
# HTTP статус: 200
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Нет ключа boosterStats
# Добавляем заголовки и данные
# Дата и время последнего обновления: 2025-11-26 21:37:13
