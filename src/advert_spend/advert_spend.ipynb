# %%
from utils_adv_spend import main_adv_spend

if __name__== "__main__":
    days_count = 1
    main_adv_spend()

# %%
# Out:
# Добавляем только данные
# Дата и время последнего обновления: 2025-11-26 22:15:15
