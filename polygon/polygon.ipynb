# %%
import sys
from pathlib import Path

# 1. Определяем корень проекта
# (подбираем количество .parent, чтобы попасть в max_projects)
project_root = Path.cwd().parent

# 2. Добавляем корень в пути поиска модулей
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# 3. Проверяем, что путь добавлен
print(f"✅ Project root: {project_root}")
print(f"✅ Sys path: {sys.path[:3]}...")
# Out:
# ✅ Project root: d:\Pytnon_scripts\ba_name
# ✅ Sys path: ['d:\\Pytnon_scripts\\ba_name', 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python313\\DLLs']...

# %%
import logging
import pandas as pd
import aiohttp
import asyncio
from datetime import datetime, timedelta

from src.price.price_server import fetch_get_price
from src.core.utils_general import load_api_tokens
from src.core.config import google_tabs
from src.core.my_gspread import GoogleTabs

# %%
nm_ids = get_nm_ids()
nm_ids
# Out:
# ✅ Успешное подключение к Наш Файл УУ ( Акселерация) -> Юнит-Экономика
# [398400810,
#  398400809,
#  159221368,
#  170598570,
#  159222686,
#  170602860,
#  242981834,
#  222683424,
#  158994099,
#  224050073,
#  224050074,
#  222373714,
#  222551732,
#  222551730,
#  222373715,
#  222373713,
#  222371913,
#  222551731,
#  171043415,
#  546333547,
#  546335814,
#  546335813,
#  703679220]

# %%
nm_ids = [
    398400810,
    398400809,
    159221368,
    170598570,
    159222686,
    170602860,
    242981834,
    222683424,
    158994099,
    224050073,
    224050074
]
data = await fetch_get_price(nm_ids)
# Out:
# 🚀 Запускаем сбор для 1 аккаунтов...
# 🏁 Сбор завершен. Итого получено цен для 11 позиций.

# %%
# 1. Создаем пустой список для хранения всех строк
all_rows = []

for item in data:
    # 2. Извлекаем данные
    nm_id = item.get('nmID')
    vendor_code = item.get('vendorCode')
    
    # достаем цену из первого размера
    sizes = item.get('sizes', [])
    if sizes:
        price = sizes[0].get('price')
        discounted_price = sizes[0].get('discountedPrice')
    else:
        price = None
        discounted_price = None

    # 3. Создаем словарь для каждой итерации
    row = {
        'nm_id': nm_id,
        'vendor_code': vendor_code,
        'price': price,
        'discounted_price': discounted_price
    }
    
    # 4. Добавляем этот словарь в наш список
    all_rows.append(row)

# 5. Создаем DataFrame из списка словарей
# Убираем index=False, Pandas сам проставит индексы 0, 1, 2...
df = pd.DataFrame(all_rows)

# %%
df.head()
# Out:
#        nm_id       vendor_code  price  discounted_price
# 0  398400810  ДжинсСарСветлСин   8243           4368.79
# 1  398400809   ДжинсСарТемнСин   8080           4282.40
# 2  170602860            150101   5423           2603.04
# 3  222683424        150101Лого   5423           2603.04
# 4  242981834       150101Красн   5423           2603.04

# %%
{"wilds": [{"wild": "wild1004", "count": 4}, {"wild": "wild1631", "count": 4}, {"wild": "wild1636", "count": 5}, {"wild": "wild1637", "count": 3}, {"wild": "wild164", "count": 3}, {"wild": "wild1768", "count": 4}, {"wild": "wild1826", "count": 30}, {"wild": "wild1982", "count": 4}, {"wild": "wild659", "count": 6}, {"wild": "wild772", "count": 2}, {"wild": "wild150", "count": 8}, {"wild": "wild1332", "count": 6}, {"wild": "wild1730", "count": 1}, {"wild": "wild1756", "count": 2}, {"wild": "wild1776", "count": 7}, {"wild": "wild1824", "count": 23}, {"wild": "wild1825", "count": 21}, {"wild": "wild1615", "count": 4}, {"wild": "wild1973", "count": 6}, {"wild": "wild1975", "count": 2}, {"wild": "wild1496", "count": 6}, {"wild": "wild172", "count": 6}, {"wild": "wild1767", "count": 1}, {"wild": "wild1970", "count": 6}, {"wild": "wild1977", "count": 5}, {"wild": "wild858", "count": 4}, {"wild": "wild1567", "count": 8}, {"wild": "wild1543", "count": 8}, {"wild": "wild1577", "count": 4}, {"wild": "wild1621", "count": 4}, {"wild": "wild1641", "count": 10}, {"wild": "wild654", "count": 4}, {"wild": "wild1766", "count": 4}, {"wild": "wild1849", "count": 1}, {"wild": "wild1789", "count": 4}], "supply_ids": [{"account": "ВЕКТОР5531", "order_ids": [5093151837, 5093322075, 5093471073, 5093017353, 5093025892, 5093271380, 5093690485, 5093192539, 5093193958, 5093280819, 5093280822, 5093599689, 5093026433, 5093141721, 5093494126, 5093534748, 5093528725, 5093528723, 5093528726, 5093547984, 5093222101, 5093236429, 5093279090, 5093185677], "supply_id": "WB-GI-240762357"}, {"account": "Оганесян", "order_ids": [5093627301, 5093673555, 5093698165, 5093687401, 5093687403, 5093687402, 5093321991, 5093349963, 5093653254, 5093687372], "supply_id": "WB-GI-240762364"}, {"account": "Пилосян", "order_ids": [5093237817, 5093303432, 5093386550, 5093560374, 5093588583, 5093148416, 5093081672, 5092994921, 5093012989, 5093241786, 5093334402, 5093492237, 5093674473, 5093425449, 5093426295, 5093466109, 5093468640, 5093469065, 5093472230, 5093536635, 5093558895, 5093565869, 5093565868, 5093668627, 5093686487, 5093691655, 5093514944, 5093527213, 5093687109, 5093701916], "supply_id": "WB-GI-240762365"}, {"account": "СТАРТ4040", "order_ids": [5093699448, 5093472209, 5093472210, 5093433500, 5093510850, 5093628288, 5093155710, 5093201686, 5093339323, 5093078123, 5093470407], "supply_id": "WB-GI-240762367"}, {"account": "СТАРТ7528", "order_ids": [5093324389, 5093529151, 5093534580, 5093690461, 5093513355, 5093175261, 5093457614, 5093458067, 5093661980, 5093451743], "supply_id": "WB-GI-240762356"}, {"account": "ВЕКТОР4216", "order_ids": [5093406195, 5093513468, 5093631065, 5093433478, 5093499488, 5093540099, 5093633213, 5093677443, 5093471356, 5093508003, 5093521151, 5093570278, 5093622717, 5093667074, 5093527888, 5093365377, 5093507305, 5093507303, 5093450330, 5093551175, 5093167129, 5093233144, 5093452437], "supply_id": "WB-GI-240762361"}, {"account": "ВЕКТОР7794", "order_ids": [5093690828, 5093596841], "supply_id": "WB-GI-240762360"}, {"account": "Тоноян", "order_ids": [5093595956, 5093605583, 5093625843, 5093695327, 5093624109, 5093642964, 5093694895, 5093365379], "supply_id": "WB-GI-240762359"}, {"account": "СТАРТ3925", "order_ids": [5093434526, 5093514116, 5093602706, 5093656241, 5093658863, 5093662183, 5093683884, 5093589074, 5093289182, 5093495563, 5093496583, 5093584037, 5093684365, 5093446317, 5093541223, 5093559953], "supply_id": "WB-GI-240762370"}, {"account": "Старт2", "order_ids": [5093668208], "supply_id": "WB-GI-240762369"}, {"account": "СТАРТ7409", "order_ids": [5093589573, 5093602654, 5093610355, 5093624115, 5093675757, 5093589454, 5093594198, 5093168579, 5093286574, 5093654661, 5093563895, 5093699307], "supply_id": "WB-GI-240762354"}, {"account": "СТАРТ9237", "order_ids": [5093521389, 5093546370, 5093663424, 5093208970], "supply_id": "WB-GI-240762362"}, {"account": "Вектор", "order_ids": [5093639439, 5093698182, 5093461998, 5093651489, 5093660533, 5093464471, 5093528409, 5093591827, 5093628642, 5093113441, 5093638384, 5093597699, 5093447858, 5093467016, 5093595217], "supply_id": "WB-GI-240762352"}, {"account": "ВЕКТОР8830", "order_ids": [5093644872, 5093644875, 5093644873, 5093644871, 5093644876], "supply_id": "WB-GI-240762368"}, {"account": "Хачатрян", "order_ids": [5093491409, 5093638684, 5093640609], "supply_id": "WB-GI-240762353"}, {"account": "ВЕКТОР3522", "order_ids": [5093550833, 5093615831, 5093627769, 5093355296, 5093695556], "supply_id": "WB-GI-240762363"}, {"account": "Вектор2", "order_ids": [5093642854, 5093327415, 5093280646, 5093478874, 5093661857, 5093634557, 5093158863, 5093351752, 5093352688, 5093503305, 5093477782, 5093646171, 5093420167, 5093672395, 5093685958, 5093437833, 5093455715, 5093487482, 5093510975, 5093531700, 5093580856, 5093595647, 5093665657, 5093683768, 5093697386, 5093625131], "supply_id": "WB-GI-240762351"}, {"account": "Даниелян", "order_ids": [5093545388, 5093548216, 5093417981, 5093578707, 5093699927, 5093705235, 5093231854, 5093536385, 5093058172], "supply_id": "WB-GI-240762366"}, {"account": "ВЕКТОР3745", "order_ids": [5093616436, 5093655674, 5093668790, 5093694672], "supply_id": "WB-GI-240762358"}, {"account": "СТАРТ8748", "order_ids": [5093641254, 5093176939], "supply_id": "WB-GI-240762371"}], "operation_id": "supply_1779618413_fa5211cb_fiz", "order_qr_map": {"5092994921": "54393478856", "5093012989": "54393496895", "5093017353": "54393501262", "5093025892": "54393509403", "5093026433": "54393509944", "5093058172": "54393541667", "5093078123": "54393561608", "5093081672": "54393565150", "5093113441": "54393596912", "5093141721": "54393625187", "5093148416": "54393631881", "5093151837": "54393635301", "5093155710": "54393639170", "5093158863": "54393642305", "5093167129": "54393650585", "5093168579": "54393652034", "5093175261": "54393658710", "5093176939": "54393660387", "5093185677": "54393669119", "5093192539": "54393675975", "5093193958": "54393677268", "5093201686": "54393685124", "5093208970": "54393692404", "5093222101": "54393705511", "5093231854": "54393715267", "5093233144": "54393716558", "5093236429": "54393719843", "5093237817": "54393721231", "5093241786": "54393725199", "5093271380": "54393754789", "5093279090": "54393762832", "5093280646": "54393764050", "5093280819": "54393764224", "5093280822": "54393764227", "5093286574": "54393769974", "5093289182": "54393772582", "5093303432": "54393786826", "5093321991": "54393805379", "5093322075": "54393805438", "5093324389": "54393807646", "5093327415": "54393810800", "5093334402": "54393817788", "5093339323": "54393822577", "5093349963": "54393833342", "5093351752": "54393835132", "5093352688": "54393836056", "5093355296": "54393838674", "5093365377": "54393848723", "5093365379": "54393848729", "5093386550": "54393869883", "5093406195": "54393889533", "5093417981": "54393901319", "5093420167": "54393903503", "5093425449": "54393908653", "5093426295": "54393909627", "5093433478": "54393916805", "5093433500": "54393916830", "5093434526": "54393917854", "5093437833": "54393921160", "5093446317": "54393928482", "5093447858": "54393930146", "5093450330": "54393932624", "5093451743": "54393934039", "5093452437": "54393934726", "5093455715": "54393939281", "5093457614": "54393941177", "5093458067": "54393941634", "5093461998": "54393945105", "5093464471": "54393947574", "5093466109": "54393949215", "5093467016": "54393950122", "5093468640": "54393951744", "5093469065": "54393952168", "5093470407": "54393953511", "5093471073": "54393954100", "5093471356": "54393954385", "5093472209": "54393955309", "5093472210": "54393955311", "5093472230": "54393955332", "5093477782": "54393960879", "5093478874": "54393961971", "5093487482": "54393970562", "5093491409": "54393974494", "5093492237": "54393975322", "5093494126": "54393977211", "5093495563": "54393978646", "5093496583": "54393979441", "5093499488": "54393982348", "5093503305": "54393986164", "5093507303": "54393990157", "5093507305": "54393990162", "5093508003": "54393990844", "5093510850": "54393993705", "5093510975": "54393993829", "5093513355": "54393996207", "5093513468": "54393996321", "5093514116": "54393996968", "5093514944": "54393997798", "5093521151": "54394004005", "5093521389": "54394004133", "5093527213": "54394010065", "5093527888": "54394010740", "5093528409": "54394011260", "5093528723": "54394011575", "5093528725": "54394011583", "5093528726": "54394011585", "5093529151": "54394011999", "5093531700": "54394014550", "5093534580": "54394017431", "5093534748": "54394017597", "5093536385": "54394019234", "5093536635": "54394019484", "5093540099": "54394023707", "5093541223": "54394024831", "5093545388": "54393937428", "5093546370": "54394028624", "5093547984": "54394030232", "5093548216": "54394030468", "5093550833": "54394033082", "5093551175": "54394033424", "5093558895": "54394041142", "5093559953": "54394042197", "5093560374": "54394042621", "5093563895": "54394046138", "5093565868": "54394048111", "5093565869": "54394048117", "5093570278": "54394052519", "5093578707": "54394060948", "5093580856": "54394063097", "5093584037": "54394066140", "5093588583": "54394070689", "5093589074": "54394071309", "5093589454": "54394071689", "5093589573": "54394071806", "5093591827": "54394074056", "5093594198": "54394076432", "5093595217": "54394077321", "5093595647": "54394077880", "5093595956": "54394078189", "5093596841": "54394079075", "5093597699": "54394079933", "5093599689": "54394081922", "5093602654": "54394084886", "5093602706": "54394084931", "5093605583": "54394087814", "5093610355": "54394092581", "5093615831": "54394098056", "5093616436": "54394098661", "5093622717": "54392068940", "5093624109": "54392070196", "5093624115": "54392070205", "5093625131": "54392071094", "5093625843": "54392071701", "5093627301": "54392073026", "5093627769": "54394103847", "5093628288": "54392073884", "5093628642": "54392074238", "5093631065": "54394114517", "5093633213": "54394116441", "5093634557": "54394117785", "5093638384": "54394121554", "5093638684": "54394121839", "5093639439": "54394122602", "5093640609": "54394123780", "5093641254": "54394124426", "5093642854": "54394126028", "5093642964": "54394126136", "5093644871": "54394128044", "5093644872": "54394128042", "5093644873": "54394128046", "5093644875": "54394128048", "5093644876": "54394128047", "5093646171": "54394129342", "5093651489": "54394134660", "5093653254": "54394136424", "5093654661": "54394137778", "5093655674": "54394138792", "5093656241": "54394139359", "5093658863": "54394141978", "5093660533": "54394143647", "5093661857": "54394144969", "5093661980": "54394145092", "5093662183": "54394145295", "5093663424": "54394146537", "5093665657": "54394148767", "5093667074": "54394150180", "5093668208": "54394151314", "5093668627": "54394151732", "5093668790": "54394151895", "5093672395": "54394155497", "5093673555": "54394156658", "5093674473": "54394157575", "5093675757": "54394158857", "5093677443": "54394160544", "5093683768": "54394166858", "5093683884": "54394166984", "5093684365": "54394167464", "5093685958": "54394168969", "5093686487": "54394169367", "5093687109": "54394170122", "5093687372": "54394170384", "5093687401": "54394170414", "5093687402": "54394170416", "5093687403": "54394170415", "5093690461": "54394173474", "5093690485": "54394173498", "5093690828": "54394173839", "5093691655": "54394174667", "5093694672": "54394177685", "5093694895": "54394177907", "5093695327": "54394178343", "5093695556": "54394178567", "5093697386": "54394180397", "5093698165": "54394181176", "5093698182": "54394181192", "5093699307": "54394182318", "5093699448": "54394182457", "5093699927": "54394182938", "5093701916": "54394184923", "5093705235": "54394188236"}, "order_wild_map": {"5092994921": "wild1776", "5093012989": "wild1776", "5093017353": "wild1631", "5093025892": "wild1631", "5093026433": "wild1637", "5093058172": "wild858", "5093078123": "wild1975", "5093081672": "wild1756", "5093113441": "wild1849", "5093141721": "wild164", "5093148416": "wild1730", "5093151837": "wild1004", "5093155710": "wild1973", "5093158863": "wild1789", "5093167129": "wild1982", "5093168579": "wild1621", "5093175261": "wild1767", "5093176939": "wild654", "5093185677": "wild772", "5093192539": "wild1636", "5093193958": "wild1636", "5093201686": "wild1973", "5093208970": "wild1977", "5093222101": "wild1982", "5093231854": "wild1970", "5093233144": "wild858", "5093236429": "wild659", "5093237817": "wild1332", "5093241786": "wild1776", "5093271380": "wild1631", "5093279090": "wild659", "5093280646": "wild1766", "5093280819": "wild1636", "5093280822": "wild1636", "5093286574": "wild1621", "5093289182": "wild1621", "5093303432": "wild1332", "5093321991": "wild659", "5093322075": "wild1004", "5093324389": "wild1496", "5093327415": "wild1756", "5093334402": "wild1776", "5093339323": "wild1973", "5093349963": "wild659", "5093351752": "wild1789", "5093352688": "wild1789", "5093355296": "wild1768", "5093365377": "wild1973", "5093365379": "wild1982", "5093386550": "wild1332", "5093406195": "wild1496", "5093417981": "wild1825", "5093420167": "wild1825", "5093425449": "wild1824", "5093426295": "wild1824", "5093433478": "wild1825", "5093433500": "wild1825", "5093434526": "wild1543", "5093437833": "wild1826", "5093446317": "wild654", "5093447858": "wild1977", "5093450330": "wild1977", "5093451743": "wild772", "5093452437": "wild858", "5093455715": "wild1826", "5093457614": "wild1825", "5093458067": "wild1826", "5093461998": "wild1766", "5093464471": "wild1826", "5093466109": "wild1824", "5093467016": "wild1977", "5093468640": "wild1824", "5093469065": "wild1824", "5093470407": "wild1982", "5093471073": "wild1004", "5093471356": "wild1826", "5093472209": "wild1615", "5093472210": "wild1615", "5093472230": "wild1824", "5093477782": "wild1824", "5093478874": "wild1766", "5093487482": "wild1826", "5093491409": "wild172", "5093492237": "wild1776", "5093494126": "wild164", "5093495563": "wild1641", "5093496583": "wild1641", "5093499488": "wild1825", "5093503305": "wild1789", "5093507303": "wild1973", "5093507305": "wild1973", "5093508003": "wild1826", "5093510850": "wild1825", "5093510975": "wild1826", "5093513355": "wild172", "5093513468": "wild150", "5093514116": "wild1543", "5093514944": "wild1825", "5093521151": "wild1826", "5093521389": "wild1577", "5093527213": "wild1825", "5093527888": "wild1970", "5093528409": "wild1826", "5093528723": "wild1768", "5093528725": "wild1768", "5093528726": "wild1768", "5093529151": "wild1496", "5093531700": "wild1826", "5093534580": "wild1496", "5093534748": "wild164", "5093536385": "wild1970", "5093536635": "wild1824", "5093540099": "wild1825", "5093541223": "wild654", "5093545388": "wild1824", "5093546370": "wild1577", "5093547984": "wild1826", "5093548216": "wild1824", "5093550833": "wild172", "5093551175": "wild1977", "5093558895": "wild1824", "5093559953": "wild654", "5093560374": "wild1332", "5093563895": "wild1641", "5093565868": "wild1824", "5093565869": "wild1824", "5093570278": "wild1826", "5093578707": "wild1825", "5093580856": "wild1826", "5093584037": "wild1641", "5093588583": "wild1332", "5093589074": "wild1577", "5093589454": "wild1615", "5093589573": "wild1567", "5093591827": "wild1826", "5093594198": "wild1615", "5093595217": "wild858", "5093595647": "wild1826", "5093595956": "wild150", "5093596841": "wild1826", "5093597699": "wild1975", "5093599689": "wild1636", "5093602654": "wild1567", "5093602706": "wild1543", "5093605583": "wild150", "5093610355": "wild1567", "5093615831": "wild172", "5093616436": "wild1824", "5093622717": "wild1826", "5093624109": "wild1567", "5093624115": "wild1567", "5093625131": "wild1970", "5093625843": "wild150", "5093627301": "wild1004", "5093627769": "wild172", "5093628288": "wild1826", "5093628642": "wild1826", "5093631065": "wild150", "5093633213": "wild1825", "5093634557": "wild1776", "5093638384": "wild1970", "5093638684": "wild1824", "5093639439": "wild1637", "5093640609": "wild1970", "5093641254": "wild1825", "5093642854": "wild172", "5093642964": "wild1567", "5093644871": "wild1641", "5093644872": "wild1641", "5093644873": "wild1641", "5093644875": "wild1641", "5093644876": "wild1641", "5093646171": "wild1824", "5093651489": "wild1824", "5093653254": "wild659", "5093654661": "wild1621", "5093655674": "wild1824", "5093656241": "wild1543", "5093658863": "wild1543", "5093660533": "wild1824", "5093661857": "wild1766", "5093661980": "wild1826", "5093662183": "wild1543", "5093663424": "wild1577", "5093665657": "wild1826", "5093667074": "wild1826", "5093668208": "wild1543", "5093668627": "wild1824", "5093668790": "wild1824", "5093672395": "wild1825", "5093673555": "wild150", "5093674473": "wild1776", "5093675757": "wild1567", "5093677443": "wild1825", "5093683768": "wild1826", "5093683884": "wild1543", "5093684365": "wild1641", "5093685958": "wild1825", "5093686487": "wild1824", "5093687109": "wild1825", "5093687372": "wild659", "5093687401": "wild1826", "5093687402": "wild1826", "5093687403": "wild1826", "5093690461": "wild1496", "5093690485": "wild1631", "5093690828": "wild1496", "5093691655": "wild1824", "5093694672": "wild1825", "5093694895": "wild1567", "5093695327": "wild150", "5093695556": "wild1826", "5093697386": "wild1826", "5093698165": "wild150", "5093698182": "wild1637", "5093699307": "wild1826", "5093699448": "wild1332", "5093699927": "wild1825", "5093701916": "wild1825", "5093705235": "wild1825"}}
